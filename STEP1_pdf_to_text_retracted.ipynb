# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/MyDrive/Applied Data Science/Thesis/Code/Downloads (paper pdfs)/Downloads_Retracted_11_Journals'
# Out:
# /content/drive/MyDrive/Applied Data Science/Thesis/Code/Downloads (paper pdfs)/Downloads_Retracted_11_Journals

# %%
import os
files = os.listdir('.')

# %%
# !pip install pymupdf

# %%
import pandas as pd
import fitz  # this is pymupdf
df_retracted = pd.DataFrame(columns=['DOI', 'Content', 'Retracted'])
for study in files:
  try:
    with fitz.open(study) as doc:
        text = ""
        for page in doc:
            text += page.get_text()
        df_retracted = df_retracted.append({'DOI': study, 'Content': text, 'Retracted': 1}, ignore_index=True)
  except:
    pass

df_retracted
# Out:
#           DOI                                            Content Retracted
# 0     r87.pdf   \n \nCORROSION INHIBITORS BASED ON HETEROCYCL...         1
# 1     r89.pdf  Cortisol as a Prognostic Marker of Short-Term ...         1
# 2     r90.pdf  High-Affinity Naloxone Binding to Filamin A Pr...         1
# 3     r91.pdf  Insulin-Like Growth Factor-1 as a Prognostic M...         1
# 4     r93.pdf  Plasma D-Dimer Levels Are Associated with Stro...         1
# ..        ...                                                ...       ...
# 755  r179.pdf  ORIGINAL PAPER\nRainfall forecast and computer...         1
# 756  r151.pdf  Hypoxia-Inducible MiR-210 Is an Independent Pr...         1
# 757  r637.pdf  Cell–cell signaling in Xanthomonas campestris\...         1
# 758  r623.pdf  Impaired lipid metabolism by age-dependent DNA...         1
# 759  r145.pdf  Enhanced Translation of mRNAs Encoding Protein...         1
#
# [760 rows x 3 columns]

# %%
df_retracted.to_csv('/content/drive/MyDrive/Applied Data Science/Thesis/Code/Data (CSV)/retracted_11_journals.csv', index=False, encoding = 'utf-8-sig')
