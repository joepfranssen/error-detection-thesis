# %% [markdown]
# Connect to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/Applied Data Science/Thesis/Code'
# Out:
# /content/drive/MyDrive/Applied Data Science/Thesis/Code

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# Load csv files of retracted and non-retracted articles

# %%
non_retracted = pd.read_csv('Data (CSV)/balanced_non_retracted_11_journals.csv', encoding="utf-8-sig")

# %%
retracted = pd.read_csv('Data (CSV)/balanced_retracted_11_journals.csv', encoding="utf-8-sig")

# %% [markdown]
# Some words have been cut off with a - and new line. To get the original words, the -\n is removed

# %%
non_retracted = non_retracted.replace({'-\n': ''}, regex = True)

# %%
retracted = retracted.replace({'-\n': ''}, regex = True)

# %% [markdown]
# Remove \n for both retracted and non-retracted papers

# %%
non_retracted = non_retracted.replace({'\n': ' '}, regex = True)

# %%
retracted = retracted.replace({'\n': ' '}, regex = True)

# %% [markdown]
# Concat to one dataframe

# %%
papers = pd.concat([non_retracted, retracted], ignore_index=True)

# %% [markdown]
# Remove rows with missing values

# %%
papers['Content'].dropna(inplace=True)

# %% [markdown]
# Check for duplicates (retracted)

# %%
papers[(papers.ID == 'r442') | (papers.ID == 'r443')]
# Out:
#       Unnamed: 0 DOI_x                                            Content  \
# 2191         337   NaN  l-Oxido-bis({4,4000-dibromo-2,2000-[ethane1,2-...
# 2193         346   NaN  l-Oxido-bis({4,4000-dibromo-2,2000-[ethane1,2-...
#
#       Retracted    ID  Unnamed: 0.1  Unnamed: 0.1.1 Publication Type Authors  \
# 2191          1  r442           442             NaN              NaN     NaN
# 2193          1  r443           443             NaN              NaN     NaN
#
#       Book Authors  ...       RetractionDate              RetractionDOI  \
# 2191           NaN  ...  2012-07-01 00:00:00  10.1107/S1600536811037603
# 2193           NaN  ...  2012-07-01 00:00:00  10.1107/S1600536811037603
#
#      RetractionPubMedID    OriginalPaperDate           OriginalPaperDOI  \
# 2191         22807693.0  2007-12-01 00:00:00  10.1107/S1600536807057996
# 2193         22807693.0  2007-11-01 00:00:00  10.1107/S1600536807051008
#
#      OriginalPaperPubMedID RetractionNature  \
# 2191                   0.0       Retraction
# 2193                   0.0       Retraction
#
#                                                  Reason  Paywalled  \
# 2191  +Error in Data;+Falsification/Fabrication of D...         No
# 2193  +Error in Data;+Falsification/Fabrication of D...         No
#
#                                                   Notes
# 2191  This retraction covers 28 articles (13 itemize...
# 2193  This retraction covers 28 articles (13 itemize...
#
# [2 rows x 100 columns]

# %%
dup = papers[papers.duplicated(subset=['RetractionDOI'])]
dup_rdois = list(dup.RetractionDOI.unique())

notremove = ['unavailable', np.nan]
toremove = [duprdoi for duprdoi in dup_rdois if duprdoi not in notremove]

papers = papers[~papers.RetractionDOI.isin(toremove)]

# %%
papers[(papers.ID == 'r442') | (papers.ID == 'r443')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DOI_x, Content, Retracted, ID, Unnamed: 0.1, Unnamed: 0.1.1, Publication Type, Authors, Book Authors, Book Editors, Book Group Authors, Author Full Names, Book Author Full Names, Group Authors, Article Title, Source Title, Book Series Title, Book Series Subtitle, Language, Document Type, Conference Title, Conference Date, Conference Location, Conference Sponsor, Conference Host, Author Keywords, Keywords Plus, Abstract, Addresses, Affiliations, Reprint Addresses, Email Addresses, Researcher Ids, ORCIDs, Funding Orgs, Funding Name Preferred, Funding Text, Cited References, Cited Reference Count, Times Cited, WoS Core, Times Cited, All Databases, 180 Day Usage Count, Since 2013 Usage Count, Publisher, Publisher City, Publisher Address, ISSN, eISSN, ISBN, Journal Abbreviation, Journal ISO Abbreviation, Publication Date, Publication Year, Volume, Issue, Part Number, Supplement, Special Issue, Meeting Abstract, Start Page, End Page, Article Number, DOI_y, Book DOI, Early Access Date, Number of Pages, WoS Categories, Web of Science Index, Research Areas, IDS Number, Pubmed Id, Open Access Designations, Highly Cited Status, Hot Paper Status, Date of Export, UT (Unique WOS ID), index, r, year, DOI, Record ID, Title, Subject, Institution, Journal, Country, Author, URLS, ArticleType, RetractionDate, RetractionDOI, RetractionPubMedID, OriginalPaperDate, OriginalPaperDOI, OriginalPaperPubMedID, RetractionNature, Reason, Paywalled, Notes]
# Index: []
#
# [0 rows x 100 columns]

# %%
len(papers)
# Out:
# 2421

# %% [markdown]
# Check for duplicates non retracted

# %%
non_retracted[non_retracted.duplicated(subset=['DOI_y'])]
# Out:
#       Unnamed: 0       DOI_x  \
# 92           321  nr1004.pdf
# 93           322  nr1005.pdf
# 99           328  nr1011.pdf
# 102          331  nr1014.pdf
# 104          333  nr1016.pdf
# ...          ...         ...
# 1643        1665   nr964.pdf
# 1644        1667   nr965.pdf
# 1645        1669   nr966.pdf
# 1646        1671   nr967.pdf
# 1647        1673   nr968.pdf
#
#                                                 Content  Retracted      ID  \
# 92    ORIGINAL PAPER Morphometric analysis of a badl...          0  nr1004
# 93    ORIGINAL PAPER Analysis of compressibility and...          0  nr1005
# 99    ORIGINAL PAPER Ultrasonic velocity as a tool f...          0  nr1011
# 102   ORIGINAL PAPER A GIS-based statistical model f...          0  nr1014
# 104   ORIGINAL PAPER Time-space analysis of groundwa...          0  nr1016
# ...                                                 ...        ...     ...
# 1643  Advances in targeting and heterologous express...          0   nr964
# 1644  Recent advances in the production of polyols f...          0   nr965
# 1645  www.rsc.org/advances RSC Advances This is an A...          0   nr966
# 1646  High performance nano-sized LiMn1�xFexPO4 cath...          0   nr967
# 1647  A large-volume manufacturing of multi-crystall...          0   nr968
#
#       Unnamed: 0.1  Unnamed: 0.1.1 Publication Type  \
# 92            1003            1004                J
# 93            1004            1005                J
# 99            1010            1011                J
# 102           1013            1014                J
# 104           1015            1016                J
# ...            ...             ...              ...
# 1643           963             964                J
# 1644           964             965                J
# 1645           965             966                J
# 1646           966             967                J
# 1647           967             968                J
#
#                                                 Authors  Book Authors  ...  \
# 92          Celi, LA; Citi, L; Ghassemi, M; Pollard, TJ           NaN  ...
# 93                              Savage, CJ; Vickers, AJ           NaN  ...
# 99                             Griebeler, EM; Werner, J           NaN  ...
# 102    Nugent, RA; Husain, MJ; Kostova, D; Chaloupka, F           NaN  ...
# 104                                         Goodkind, D           NaN  ...
# ...                                                 ...           ...  ...
# 1643                           Qiao, YM; Yu, RL; Zhu, P           NaN  ...
# 1644  Liu, XR; Wang, XC; Yao, SX; Jiang, YJ; Guan, J...           NaN  ...
# 1645                                           Yang, ZH           NaN  ...
# 1646  Lei, ZH; Naveed, A; Lei, JY; Wang, JL; Yang, J...           NaN  ...
# 1647  Zhang, YB; Tao, JH; Chen, YF; Xiong, Z; Zhong,...           NaN  ...
#
#       IDS Number   Pubmed Id  \
# 92         HH6AH  30645625.0
# 93         496KI  19763261.0
# 99         FX7ND  29489816.0
# 102        LP9GK  32027710.0
# 104        LN1FJ  31693668.0
# ...          ...         ...
# 1643       JQ3IZ  35530690.0
# 1644       AR6RQ         NaN
# 1645       DY8ON         NaN
# 1646       FG5BL         NaN
# 1647       DP8CP         NaN
#
#                                Open Access Designations  Highly Cited Status  \
# 92    gold, Green Published, Green Submitted, Green ...                  NaN
# 93               gold, Green Published, Green Submitted                  NaN
# 99               Green Published, gold, Green Submitted                  NaN
# 102                               Green Published, gold                  NaN
# 104                               Green Published, gold                  NaN
# ...                                                 ...                  ...
# 1643                                               gold                  NaN
# 1644                                                NaN                  NaN
# 1645                                                NaN                  NaN
# 1646                                               gold                  NaN
# 1647                                                NaN                  NaN
#
#      Hot Paper Status Date of Export   UT (Unique WOS ID)  index   r    year
# 92                NaN     2022-05-24  WOS:000455810200021   1004  nr  1970.0
# 93                NaN     2022-05-24  WOS:000269970400013   1005  nr  1970.0
# 99                NaN     2022-05-24  WOS:000426276000001   1011  nr  1970.0
# 102               NaN     2022-05-24  WOS:000534623800049   1014  nr  1970.0
# 104               NaN     2022-05-24  WOS:000532690100009   1016  nr  1970.0
# ...               ...            ...                  ...    ...  ..     ...
# 1643              NaN     2022-05-12  WOS:000498844000050    964  nr  1970.0
# 1644              NaN     2022-05-12  WOS:000343711000096    965  nr  1970.0
# 1645              NaN     2022-05-12  WOS:000385389800124    966  nr  1970.0
# 1646              NaN     2022-05-12  WOS:000410306700042    967  nr  1970.0
# 1647              NaN     2022-05-12  WOS:000378725800033    968  nr  1970.0
#
# [189 rows x 80 columns]

# %% [markdown]
# Original scraped content is kept as OG_content.

# %%
papers['All content'] = papers['Content']

# %% [markdown]
# Try to remove retraction notice

# %%
len(papers[papers['All content'].str.contains('Notice of Retraction')==True])
# Out:
# 0

# %%
papers.Content = papers.Content.str.replace(r'^Notice of Retraction.+ieee\.org\.', '', regex = True)

# %% [markdown]
# Remove papers from non-retracted that are actually retracted

# %%
len(papers)
# Out:
# 2421

# %%
non_retracted = papers[papers.Retracted == 0]
doi_toremove = non_retracted[non_retracted["Content"].str.contains('Retraction|retraction|Retracted|retracted|retract|Retract|withdrawn|Withdraw')==True].DOI_x
papers = papers[~papers.DOI_x.isin(doi_toremove)]

# %%
len(papers)
# Out:
# 2374

# %% [markdown]
# Splitting the content into 4 parts: 1) Abstract, 2) main content (Introduction-Results), 3) Discussion/Conclusion and 4) References.

# %%
papers['References'] = papers['Content'].str.split(r'References|R E F E R E N C E S|REFERENCES|r e f e r e n c e s|Reference List', 2, expand = True)[1]
papers['Content'] = papers['Content'].str.split(r'References|R E F E R E N C E S|REFERENCES|r e f e r e n c e s|Reference List', 2, expand = True)[0]

# %%
papers['Discussion / Conclusion'] = papers['Content'].str.split(r'Discussion|D I S C U S S I O N|DISCUSSION|d i s c u s s i o n|Conclusion|C O N C L U S I O N|CONCLUSION|c o n c l u s i o n', 2, expand = True)[1]
papers['Content'] = papers['Content'].str.split(r'Discussion|D I S C U S S I O N|DISCUSSION|d i s c u s s i o n|Conclusion|C O N C L U S I O N|CONCLUSION|c o n c l u s i o n', 2, expand = True)[0]

# %%
papers['Main content'] = papers['Content'].str.split(r'Introduction|I N T R O D U C T I O N|INTRODUCTION|i n t r o d u c t i o n', 2, expand = True)[1]
papers['Title + Abstract'] = papers['Content'].str.split(r'Introduction|I N T R O D U C T I O N|INTRODUCTION|i n t r o d u c t i o n', 2, expand = True)[0]
papers.drop('Content', axis=1, inplace=True)

# %% [markdown]
# Check for null values (NaN/None) in References: if references are missing, it is an indicator that not the original article was scraped but some text relating to the article. Thus, we decide to exclude those rows with missing values for references.

# %%
print("Total papers:", len(papers))
print("Missing main content:", papers['Main content'].isnull().sum())
print("Missing discussion/conclusion:", papers['Discussion / Conclusion'].isnull().sum())
print("Missing references:", papers['References'].isnull().sum())
# Out:
# Total papers: 2374
# Missing main content: 1126
# Missing discussion/conclusion: 594
# Missing references: 303

# %%
no_references = papers[papers['References'].isnull()]
papers = papers[~papers.ID.isin(no_references.ID)]

# %%
print("Total papers:", len(papers))
print("Missing main content:", papers['Main content'].isnull().sum())
print("Missing discussion/conclusion:", papers['Discussion / Conclusion'].isnull().sum())
print("Missing references:", papers['References'].isnull().sum())
# Out:
# Total papers: 2071
# Missing main content: 897
# Missing discussion/conclusion: 383
# Missing references: 0

# %%
no_introduction = papers[papers['Main content'].isnull()]
papers = papers[~papers.ID.isin(no_introduction.ID)]

# %%
print("Total papers:", len(papers))
print("Missing main content:", papers['Main content'].isnull().sum())
print("Missing discussion/conclusion:", papers['Discussion / Conclusion'].isnull().sum())
print("Missing references:", papers['References'].isnull().sum())
# Out:
# Total papers: 1174
# Missing main content: 0
# Missing discussion/conclusion: 106
# Missing references: 0

# %%
no_discussion = papers[papers['Discussion / Conclusion'].isnull()]
papers = papers[~papers.ID.isin(no_discussion.ID)]

# %%
print("Total papers:", len(papers))
print("Missing main content:", papers['Main content'].isnull().sum())
print("Missing discussion/conclusion:", papers['Discussion / Conclusion'].isnull().sum())
print("Missing references:", papers['References'].isnull().sum())
# Out:
# Total papers: 1068
# Missing main content: 0
# Missing discussion/conclusion: 0
# Missing references: 0

# %% [markdown]
# Define the important columns

# %%
papers.columns
# Out:
# Index(['Unnamed: 0', 'DOI_x', 'Retracted', 'ID', 'Unnamed: 0.1',
#        'Unnamed: 0.1.1', 'Publication Type', 'Authors', 'Book Authors',
#        'Book Editors',
#        ...
#        'OriginalPaperPubMedID', 'RetractionNature', 'Reason', 'Paywalled',
#        'Notes', 'All content', 'References', 'Discussion / Conclusion',
#        'Main content', 'Title + Abstract'],
#       dtype='object', length=104)

# %%
papers = papers[['All content', 'Title + Abstract', 'Main content', 'Discussion / Conclusion', 'References', 'ID', 'Retracted']]
# Out:
#                                             All content  \
# 0               Journal of Fundamental and Applied S...
# 1               Journal of Fundamental and Applied S...
# 2         THE STUDY OF DECORATIVE ELEMENTS OF SIAMIA...
# 3               Journal of Fundamental and Applied  ...
# 4             THE PROSPECTS OF USE OF ALTERNATIVE TY...
# ...                                                 ...
# 2459  © 2018 Yan et al. This work is published and l...
# 2472  © 2018 Jia et al. This work is published and l...
# 2477  O R I G I N A L R E S E A R C H lncRNA HAND2-A...
# 2479  O R I G I N A L R E S E A R C H Long Non-Codin...
# 2483  © 2015 Wang et al. This work is published by D...
#
#                                        Title + Abstract  \
# 0               Journal of Fundamental and Applied S...
# 1               Journal of Fundamental and Applied S...
# 2         THE STUDY OF DECORATIVE ELEMENTS OF SIAMIA...
# 3               Journal of Fundamental and Applied  ...
# 4             THE PROSPECTS OF USE OF ALTERNATIVE TY...
# ...                                                 ...
# 2459  © 2018 Yan et al. This work is published and l...
# 2472  © 2018 Jia et al. This work is published and l...
# 2477  O R I G I N A L R E S E A R C H lncRNA HAND2-A...
# 2479  O R I G I N A L R E S E A R C H Long Non-Codin...
# 2483  © 2015 Wang et al. This work is published by D...
#
#                                            Main content  \
# 0       Schiff bases are aldehyde - or ketone-like c...
# 1       Radio astronomical observation is affected b...
# 2         If one presumes a body and a soul for arch...
# 3       Shooting range contains high content of lead...
# 4       In the Russian Federation, as in other devel...
# ...                                                 ...
# 2459  : Minichromosome maintenance 10 (MCM10) is der...
# 2472  : Temozolomide (TMZ) is commonly used for glio...
# 2477  : Increasing evidence has shown that abnormall...
# 2479  : Long non-coding RNAs (lncRNAs) are regarded ...
# 2483   Gliomas are the most common malignant primary...
#
#                                 Discussion / Conclusion  \
# 0        3.1. Surface Pressure-Area (Π-A) Isotherms ...
# 1        Each data for each parameter was combined t...
# 2       Essentially, architecture deals with somethi...
# 3        2.1. Physico-chemical Properties for SMS an...
# 4       The implementation of scientific approach, w...
# ...                                                 ...
# 2459  : In conclusion, these results suggest that MC...
# 2472  : Taken together, our data suggest that H19 de...
# 2477  : In summary, our results illustrated that HAN...
# 2479  : Our results indicated the tumor suppressive ...
# 2483   In our study, we found lower levels of miR-13...
#
#                                              References     ID  Retracted
# 0       [1] Roy N, Pramanik HA, Paul PC, Singh TS. A...  nr580          0
# 1       [1] Hamidi Z, Shariff N. Investigation of ra...  nr601          0
# 2       Guide of Historical-Cultural Works of Mazand...  nr577          0
# 3       [1] Yong S K, Mohd Z S N, Mad A M J. Effects...  nr589          0
# 4       1. Chris Woodford. Air pollution. URL: http:...  nr543          0
# ...                                                 ...    ...        ...
# 2459    1. Torre LA, Bray F, Siegel RL, Ferlay J, Lo...   r875          1
# 2472    1. Shi J, Dong B, Cao J, Mao Y, Guan W, Peng...   r793          1
# 2477   1. Zhu Y, Yang XQ, Han CT, et al. Pathologica...   r796          1
# 2479   1. Bray F, Ferlay J, Soerjomataram I, Siegel ...   r811          1
# 2483   1. Furnari FB, Fenton T, Bachoo RM, et al. Ma...   r794          1
#
# [1068 rows x 7 columns]

# %% [markdown]
# Investigate the final dataframe

# %%
papers['ID'].iloc[0:10]
# Out:
# 0     nr580
# 1     nr601
# 2     nr577
# 3     nr589
# 4     nr543
# 5     nr533
# 6     nr530
# 11    nr549
# 12    nr552
# 13    nr556
# Name: ID, dtype: object

# %%
papers['References'].iloc[0:7]
# Out:
# 0      [1] Roy N, Pramanik HA, Paul PC, Singh TS. A...
# 1      [1] Hamidi Z, Shariff N. Investigation of ra...
# 2      Guide of Historical-Cultural Works of Mazand...
# 3      [1] Yong S K, Mohd Z S N, Mad A M J. Effects...
# 4      1. Chris Woodford. Air pollution. URL: http:...
# 5      [1] Jones J. Ch. Design Methods [Metody proy...
# 6      [1] Ramcharan B. G. Contemporary human right...
# Name: References, dtype: object

# %% [markdown]
# Save the output to CSV

# %%
papers.to_csv('/content/drive/MyDrive/Applied Data Science/Thesis/Code/Data (CSV)/preprocessing_part_1.csv')
